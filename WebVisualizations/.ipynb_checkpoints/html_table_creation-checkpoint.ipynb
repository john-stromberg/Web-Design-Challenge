# %%
import pandas as pd

# %%
weather_data = "weather_data.csv"

# %%
weather_df = pd.read_csv(weather_data)

# %%
weather_df.head()
# Out:
#    Unnamed: 0         City  Cloudiness Country        Date  Humidity    Lat  \
# 0           0       Usinsk         100      RU  1571073304        94  66.00
# 1           1      Ternate          20      PH  1571073304        69  14.29
# 2           2  Port Alfred           0      ZA  1571073305        78 -33.59
# 3           3       Avarua          75      CK  1571073306        94 -21.21
# 4           4          Vao         100      EE  1571073306        90  59.10
#
#       Lng  Max Temp  Wind Speed
# 0   57.56     37.85       11.77
# 1  120.72     81.00        2.24
# 2   26.89     66.99        8.01
# 3 -159.78     69.80        4.70
# 4   26.19     44.69       12.58

# %%
new_df = weather_df.drop(columns=['Unnamed: 0'])

# %%
new_df.head()
# Out:
#           City  Cloudiness Country        Date  Humidity    Lat     Lng  \
# 0       Usinsk         100      RU  1571073304        94  66.00   57.56
# 1      Ternate          20      PH  1571073304        69  14.29  120.72
# 2  Port Alfred           0      ZA  1571073305        78 -33.59   26.89
# 3       Avarua          75      CK  1571073306        94 -21.21 -159.78
# 4          Vao         100      EE  1571073306        90  59.10   26.19
#
#    Max Temp  Wind Speed
# 0     37.85       11.77
# 1     81.00        2.24
# 2     66.99        8.01
# 3     69.80        4.70
# 4     44.69       12.58

# %%
html = new_df.to_html("table.html")
